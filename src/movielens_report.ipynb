# %% [markdown]
# # 🎬 Анализ датасета MovieLens: Популярность ≠ Качество?
#
# ## 👋 Добро пожаловать в отчет!
#
# В этом исследовании мы работаем с датасетом **MovieLens**, который включает:
# - 🎞️ Информацию о фильмах (название, год, жанры)
# - ⭐ Пользовательские оценки и рейтинги
# - 🏷️ Теги, добавленные сообществом
# - 🔗 Дополнительные данные из IMDB (бюджет, кассовые сборы)
#
# ## 💡 Исследовательская гипотеза
#
# > Самые популярные фильмы — не обязательно самые качественные,
# > а дорогие в производстве — не всегда самые успешные.
#
# Мы проверим это утверждение шаг за шагом:
#
# 1. 🔍 **Разведочный анализ данных (EDA)** — знакомство со структурой и распределениями
# 2. 📊 **Анализ популярности** — какие фильмы чаще всего смотрят и оценивают
# 3. ⚖️ **Качество vs Популярность** — корреляция между рейтингом и количеством оценок
# 4. 💰 **Бюджет и успех** — влияет ли стоимость производства на кассовые сборы?
# 5. 🏷️ **Роль тегов** — как пользовательские метки помогают понять предпочтения аудитории
#
# ### Располагайся поудобнее, мы начинаем!⭐

# %%
# %timeit
import movielens_analysis

# %% [markdown]
# #### 🔧 Подключаем инструменты
# В этом разделе мы инициализируем основные классы для работы с данными: `Links`, `Movies`, `Ratings` и `Tags`. Это позволит нам получить доступ ко всей информации о фильмах, оценках, тегах и связях с IMDB.

# %%
# %timeit
links = movielens_analysis.Links()
movies = movielens_analysis.Movies()
ratings = movielens_analysis.Ratings()
user_obj = ratings.users
tags = movielens_analysis.Tags()

# %% [markdown]
# #### 🎬 Начнём с фильмов: что вообще есть в датасете?

# %% [markdown]
# ##### Какие жанры самые популярные?

# %%
# %timeit
top_genres = movies.dist_by_genres()
# Out:
# 🎭 ТОП-10 ЖАНРОВ:
# 1. Drama: 507 фильмов
# 2. Comedy: 365 фильмов
# 3. Romance: 208 фильмов
# 4. Thriller: 179 фильмов
# 5. Action: 158 фильмов
# 6. Adventure: 126 фильмов
# 7. Crime: 122 фильмов
# 8. Children: 100 фильмов
# 9. Sci-Fi: 69 фильмов
# 10. Fantasy: 68 фильмов

# %% [markdown]
# ##### А каков пиковый год для топовых жанров (топ3)?

# %%
# %timeit
genre = 'Drama'
productive_year = movies.get_most_productive_year_by_genre(genre)
genre = 'Comedy'
productive_year = movies.get_most_productive_year_by_genre(genre)
genre = 'Romance'
productive_year = movies.get_most_productive_year_by_genre(genre)
# Out:
# Самый "горячий" год для жанра Drama - 1995 (107 фильмов)
# Самый "горячий" год для жанра Comedy - 1995 (80 фильмов)
# Самый "горячий" год для жанра Romance - 1995 (44 фильмов)

# %% [markdown]
# ##### А как менялся выпуск фильмов по годам?

# %%
# %timeit
top_years = movies.dist_by_release()
# Out:
# 📅 КОЛИЧЕСТВО ФИЛЬМОВ ПО ГОДАМ (1987-1995):
# 1995: ████████████████████████████████████████████ 224
# 1994: ████████████████████████████████████ 184
# 1996: ████████████████████████████████████ 181
# 1993: ████████████████████ 101
# 1992: ████ 23
# 1991: ███ 15
# 1990: ███ 15
# 1989: ██ 14
# 1986: █ 9
# 1987: █ 8

# %% [markdown]
# ##### Какие фильмы "намешали" больше всего жанров?

# %%
# %timeit
mix_genres = movies.most_genres(10)
# Out:
# 🎭 САМЫЕ МНОГОЖАНРОВЫЕ ФИЛЬМЫ:
# • Aladdin and the King of Thieves (1996) — 6 жанров
# • All Dogs Go to Heaven 2 (1996) — 6 жанров
# • Beauty and the Beast (1991) — 6 жанров
# • Getaway, The (1994) — 6 жанров
# • Lion King, The (1994) — 6 жанров
# • Space Jam (1996) — 6 жанров
# • Strange Days (1995) — 6 жанров
# • Super Mario Bros. (1993) — 6 жанров
# • Aladdin (1992) — 5 жанров
# • Alice in Wonderland (1951) — 5 жанров

# %% [markdown]
# ##### А есть ли в датасете франшизы? Давайте узнаем

# %%
# %timeit
top_franchises = movies.get_top_franchises(n=5)
# Out:
# 1. Sabrina (2 фильма)

# %% [markdown]
# #### ⭐ Теперь посмотрим на оценки

# %% [markdown]
# ##### Какие фильмы получают самые высокие оценки?

# %%
# %timeit
top_movies = user_obj.top_by_ratings(10, metric='average')
# Out:
# 🏆 ТОП-10 ФИЛЬМОВ ПО AVERAGE:
# 1. Bottle Rocket (1996) (5.0 ⭐)
# 2. Canadian Bacon (1995) (5.0 ⭐)
# 3. Star Wars: Episode IV - A New Hope (1977) (5.0 ⭐)
# 4. James and the Giant Peach (1996) (5.0 ⭐)
# 5. Wizard of Oz, The (1939) (5.0 ⭐)
# 6. Citizen Kane (1941) (5.0 ⭐)
# 7. Adventures of Robin Hood, The (1938) (5.0 ⭐)
# 8. Mr. Smith Goes to Washington (1939) (5.0 ⭐)
# 9. Winnie the Pooh and the Blustery Day (1968) (5.0 ⭐)
# 10. Three Caballeros, The (1945) (5.0 ⭐)

# %% [markdown]
# ##### А если считать по медиане?

# %%
# %timeit
top_movies = user_obj.top_by_ratings(10, metric='median')
# Out:
# 🏆 ТОП-10 ФИЛЬМОВ ПО MEDIAN:
# 1. Bottle Rocket (1996) (5.0 ⭐)
# 2. Canadian Bacon (1995) (5.0 ⭐)
# 3. Star Wars: Episode IV - A New Hope (1977) (5.0 ⭐)
# 4. Tommy Boy (1995) (5.0 ⭐)
# 5. Forrest Gump (1994) (5.0 ⭐)
# 6. Fugitive, The (1993) (5.0 ⭐)
# 7. Jurassic Park (1993) (5.0 ⭐)
# 8. Tombstone (1993) (5.0 ⭐)
# 9. Dances with Wolves (1990) (5.0 ⭐)
# 10. Pinocchio (1940) (5.0 ⭐)

# %% [markdown]
# ##### Какие фильмы самые популярные по числу оценок?

# %%
# %timeit
top_movies_nr = user_obj.top_by_num_of_ratings(10)
# Out:
# 🏆 ТОП-10 ФИЛЬМОВ ПО КОЛИЧЕСТВУ ОЦЕНОК:
# • Usual Suspects, The (1995) - 4 оценки
# • Pulp Fiction (1994) - 4 оценки
# • Fugitive, The (1993) - 4 оценки
# • Schindler's List (1993) - 4 оценки
# • Batman (1989) - 4 оценки
# • Silence of the Lambs, The (1991) - 4 оценки
# • Fargo (1996) - 4 оценки
# • Aladdin (1992) - 4 оценки
# • Beauty and the Beast (1991) - 4 оценки
# • Toy Story (1995) - 3 оценки

# %% [markdown]
# ##### Как менялась активность оценивания по годам?

# %%
# %timeit
ratings_by_year = user_obj.dist_by_year()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/School21/GitLab/DS/Bootcamp1/DSB6_MovieLens_Analytics.ID_1577649-Team_TL_xhoanmel.9c84b6c2_3bdb_4e98-1/src/movielens_analysis.py:562, in Ratings.Movies.dist_by_year(self, n)
#     561 try:
# --> 562     timestamp = int(line['timestamp'])
#     563     m_year = datetime.fromtimestamp(timestamp).year
#
# ValueError: invalid literal for int() with base 10: "964982703 whwnem;wq 'lw"
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 get_ipython().run_line_magic('timeit', '')
# ----> 2 ratings_by_year = user_obj.dist_by_year()
#
# ...

# %% [markdown]
# ### 👥 Кто эти зрители?
#
# В этом блоке мы определяем самых активных пользователей и анализируем их средние оценки, чтобы понять общую тональность отзывов в сообществе.

# %% [markdown]
# ##### Кто самый активный?

# %%
# %timeit
active_users = user_obj.dist_by_activity()

# %% [markdown]
# ##### Кто ставит самые высокие оценки? Оцениваем по среднему (average) и медиане (median)

# %%
# %timeit
user_avg_ratings = user_obj.dist_by_metric(metric = 'average')
user_avg_ratings = user_obj.dist_by_metric(metric = 'median')

# %% [markdown]
# `Вывод`: топы отличаются, но средняя оценка оказалась наиболее точной метрикой

# %% [markdown]
# ##### Какие оценки ставили фильмам?

# %%
# %timeit
ratings_distribution = user_obj.dist_by_rating()

# %% [markdown]
# `Вывод`: оценки "с половинкой" ставят намного реже, чем целые"

# %% [markdown]
# ##### А кто главный скандалист? Чьи оценки наиболее противоречивы?

# %%
# %timeit
top_users = user_obj.top_controversial_users(1)

# %% [markdown]
# #### 🔥 Самые противоречивые фильмы
#
# Выявляем фильмы, которые вызывают самые жаркие споры среди зрителей, анализируя дисперсию их оценок.

# %%
# %timeit
controversial_movies = user_obj.top_controversial()

# %% [markdown]
# #### ⭐ Какой фильм однозначно отличный?
# Давайте посмотрим, кто же из фильмов стал отличником и любимчиком публики

# %%
# %timeit
top_favorite_movie = user_obj.top_by_max_ratings()

# %% [markdown]
# ### 💰 А теперь деньги
#
# Мы обращаемся к данным IMDB, чтобы узнать, какие фильмы были самыми дорогими в производстве, а какие принесли наибольшую прибыль.

# %% [markdown]
# Загружаем данные...И смотрим, кто чаще всего снимает фильмы

# %%
# %timeit
links.imdb_info = []
get_imdb = links.get_imdb(list(links.links.keys())[:50], ['Director', 'Budget', 'Cumulative Worldwide Gross', 'Runtime'])
top_directors = links.top_directors(5)

# %% [markdown]
# ##### Самые высокобюджетные фильмы

# %%
# %timeit
expensive_movies = links.most_expensive(5)

# %% [markdown]
# ##### Самые прибыльные
#
# Анализируем продолжительность фильмов и вычисляем стоимость одной минуты экранного времени для самых масштабных картин.

# %%
# %timeit
profitable_films = links.most_profitable(5)

# %% [markdown]
# ##### ⏳ Самые длинные фильмы и стоимость минуты
#
# Анализируем продолжительность фильмов и вычисляем стоимость одной минуты экранного времени для самых масштабных картин.

# %%
# %timeit
longest_movies = links.longest(n=5)
cost_per_minute = links.top_cost_per_minute(n=5)

# %% [markdown]
# ### 💰 А что пишут пользователи?
#
# Изучаем теги, которые пользователи добавляют к фильмам. Смотрим, какие из них самые длинные, многословные и часто используемые.

# %% [markdown]
# ##### 🏷️ Для разминки предлагаем посмотреть ТОП-10 тэгов по количеству слов, по количеству символов. И зафиналить самыми большими тэгами (и многословными, и посимвольно)

# %%
# %timeit
most_tags = tags.most_words_and_longest(7)

# %% [markdown]
# ##### А какие же теги самые популярные?

# %%
# %timeit
popular_tags = tags.most_popular()

# %% [markdown]
# ##### 🏷️ Распределение тегов по годам

# %%
# %timeit
tags_for_years = tags.dist_by_year()

# %% [markdown]
# #### 🏷️ Теги с определенным словом
#
# Предлагается небольшой интерактив: можем сами посмотреть, какие слова в каких тэгах встречаются

# %%
# %timeit
tags_with_word = tags.tags_with('Disney')

# %% [markdown]
# #### 📌 Пришло время подводить итог...
# 👉 Популярные фильмы ≠ самые высоко оценённые \
# 👉 Дорогие фильмы ≠ самые прибыльные \
# 👉 Пользователи сильно отличаются по поведению \
# 👉 Есть фильмы, которые реально «делят аудиторию»
# ## 💡 Гипотеза подтвердилась частично: успех фильма — это не только бюджет и не только рейтинг, а сочетание факторов + восприятие зрителей.
